# %% [markdown]
# <font size=5 face="微軟雅黑"> 作業一: </font>

# %% [markdown]
# 1. 你選的這組資料為何重要<br>
# 這組資料是來自Kaggle的dataset [BlackFriday](https://www.kaggle.com/mehdidag/black-friday)。<br>
# 讓我們可以研究不同類型的客戶(ex:年齡、居住地的不同)可能會購買的產品類型。

# %% [markdown]
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)<br>
# 這組資料來自Kaggle，是由一個零售商在黑色星期五當天記錄下當日消費者的資料以及其購買行為。

# %% [markdown]
# 3. 蒐集而來的資料型態為何<br>
# 此筆資料為一結構化資料(表格)。

# %% [markdown]
# 4. 這組資料想解決的問題如何評估<br>
# 這筆資料想解決的是分類問題，所以我認為可以用AUC來當指標去評估準確性。

# %% [markdown]
# <font size=5 face="微軟雅黑"> 作業二: </font>

# %% [markdown]
# 1. 核心問題為何 <br>
# 目標為提升業績，也就是提升車隊的營運總額。而問題就在於究竟如何提升業績呢?我認為是分析哪些因子為影響業績的重要因子(回歸問題)，透過調整這些因子使得營運總額有正向增加。

# %% [markdown]
# 2. 資料從何而來<br>
# 可以從經營的車隊得到第一手資料，透過收集每一筆單次載客的資料來分析。而我推斷，這些單次載客的資料裡，應該包含:<br>
# 該次消費總額、司機性別、計程車車種、上車區域、下車地點、司機開車行為(司機平常遭客訴多寡)、當日天氣、上車人數、使用何種叫車方式(ex:app,電話)...等

# %% [markdown]
# 3. 蒐集而來的資料型態為何<br>
# 因為蒐集來的資料為一表格，因此是結構化資料。

# %% [markdown]
# 4. 你要回答的問題，其如何評估<br>
# 透過假設檢定，去驗證該變數是否為影響因子。

# %% [markdown]
# <font size=5 face="微軟雅黑"> 作業三: </font>

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(x,y):
    """
    請完成這個 Function 後往下執行
    """
    MSE=sum((x-y)**2)/len(x)
    return MSE

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 179.020
# The Mean absolute error is 11.135
