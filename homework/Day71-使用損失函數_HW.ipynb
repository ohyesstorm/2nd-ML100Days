# %% [markdown]
# #
#
# # 作業目標:
#
#     1. 藉由固定的 dataset, 來驗證不同loss function
#     2. Dataset 的特性跟我們選用的loss function 對accrancy 的影響
#
#
# # 作業重點:
#     請分別選用 "MSE", "binary _crossentropy"
#     查看Train/test accurancy and loss rate

# %% [markdown]
# # 導入必要的函數

# %%
from keras.datasets import cifar10
import numpy as np
np.random.seed(10)

# %% [markdown]
# # 資料準備

# %%
#取得Keras Dataset
(x_img_train,y_label_train),(x_img_test,y_label_test)=cifar10.load_data()
# Out:
# ...
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
#確認 CIFAR10 Dataset 資料維度
print("train data:",'images:',x_img_train.shape,
      " labels:",y_label_train.shape) 
print("test  data:",'images:',x_img_test.shape ,
      " labels:",y_label_test.shape)
# Out:
# train data: images: (50000, 32, 32, 3)  labels: (50000, 1)
# test  data: images: (10000, 32, 32, 3)  labels: (10000, 1)

# %%
#資料正規化
x_img_train_normalize = x_img_train.astype('float32') / 255.0
x_img_test_normalize = x_img_test.astype('float32') / 255.0

# %%
#針對Label 做 ONE HOT ENCODE
from keras.utils import np_utils
y_label_train_OneHot = np_utils.to_categorical(y_label_train)
y_label_test_OneHot = np_utils.to_categorical(y_label_test)
y_label_test_OneHot.shape
# Out:
# (10000, 10)

# %% [markdown]
# # 建立模型

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D

# %%
model = Sequential()

# %%
#卷積層1

# %%
model.add(Conv2D(filters=32,kernel_size=(3,3),
                 input_shape=(32, 32,3), 
                 activation='relu', 
                 padding='same'))

# %%
model.add(Dropout(rate=0.25))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#卷積層2與池化層2

# %%
model.add(Conv2D(filters=64, kernel_size=(3, 3), 
                 activation='relu', padding='same'))

# %%
model.add(Dropout(0.25))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#建立神經網路(平坦層、隱藏層、輸出層)

# %%
model.add(Flatten())
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(1024, activation='relu'))
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(10, activation='softmax'))

# %%
#檢查model 的STACK
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# ...

# %% [markdown]
# # 載入之前訓練的模型

# %%
try:
    model.load_weights("SaveModel/cifarCnnModel.h5")
    print("載入模型成功!繼續訓練模型")
except :    
    print("載入模型失敗!開始訓練一個新模型")
# Out:
# 載入模型失敗!開始訓練一個新模型

# %% [markdown]
# # 訓練模型

# %%
# model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

'''
作業:
請分別選用 "MSE", "binary _crossentropy"
查看Train/test accurancy and loss rate
'''
# Out:
# '\n作業:\n請分別選用 "MSE", "binary _crossentropy"\n查看Train/test accurancy and loss rate\n'

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_img_train_normalize, y_label_train_OneHot,
          validation_split = 0.2, epochs = 10, batch_size = 128, verbose = 1)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 3s 10ms/step - loss: 1.7686 - accuracy: 0.3631 - val_loss: 1.2931 - val_accuracy: 0.5837
# Epoch 2/10
# 313/313 [==============================] - 3s 9ms/step - loss: 1.1981 - accuracy: 0.5708 - val_loss: 1.1452 - val_accuracy: 0.6304
# Epoch 3/10
# 313/313 [==============================] - 3s 9ms/step - loss: 1.0387 - accuracy: 0.6355 - val_loss: 1.0137 - val_accuracy: 0.6743
# Epoch 4/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.8998 - accuracy: 0.6816 - val_loss: 0.9701 - val_accuracy: 0.6776
# Epoch 5/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.8199 - accuracy: 0.7109 - val_loss: 0.9056 - val_accuracy: 0.7046
# Epoch 6/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.7287 - accuracy: 0.7489 - val_loss: 0.8742 - val_accuracy: 0.7203
# Epoch 7/10
# ...

# %%
print('Testing set accuracy:', model.evaluate(x_img_test_normalize, y_label_test_OneHot)[1])
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7899 - accuracy: 0.7295
# Testing set accuracy: 0.7294999957084656

# %% [markdown]
# ### 同個neural network架構下 用MSE這種較不適合的loss function來做

# %%
model1 = Sequential()

model1.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape = (32, 32, 3), activation='relu', padding='same'))
model1.add(Dropout(0.25))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'))
model1.add(Dropout(0.25))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Flatten())
model1.add(Dropout(0.25))

model1.add(Dense(units=1024, activation='relu'))
model1.add(Dropout(0.25))

model1.add(Dense(units=10, activation='softmax'))

# %%
model1.compile(loss='MSE', optimizer='adam', metrics=['accuracy'])
model1.fit(x_img_train_normalize, y_label_train_OneHot,
           validation_split = 0.2, epochs = 10, batch_size = 128, verbose = 1)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0827 - accuracy: 0.2833 - val_loss: 0.0669 - val_accuracy: 0.5205
# Epoch 2/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0616 - accuracy: 0.5259 - val_loss: 0.0604 - val_accuracy: 0.5758
# Epoch 3/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0548 - accuracy: 0.5839 - val_loss: 0.0543 - val_accuracy: 0.6190
# Epoch 4/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0495 - accuracy: 0.6345 - val_loss: 0.0499 - val_accuracy: 0.6442
# Epoch 5/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0445 - accuracy: 0.6709 - val_loss: 0.0457 - val_accuracy: 0.6732
# Epoch 6/10
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0401 - accuracy: 0.7113 - val_loss: 0.0436 - val_accuracy: 0.6941
# Epoch 7/10
# ...

# %%
print('Testing set accuracy:', model1.evaluate(x_img_test_normalize, y_label_test_OneHot)[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0393 - accuracy: 0.7193
# Testing set accuracy: 0.7192999720573425
