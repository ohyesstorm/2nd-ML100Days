# %% [markdown]
# # 作業目標:
#     運用 Keras 模組建構CNN, 了解 CNN 的架構

# %% [markdown]
# # 作業重點
# (1)嘗試比對 Dense 與 layers.Conv2D 架構NN 的差異
#
# (2) 有沒有Pooling layer, 對於參數量的差異
#
# 注意: input_shape 請勿修改

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D, Flatten, Dense

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape = (28, 28, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(25, (3, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Flatten())
model.add(Dense(units=100))
model.add(Activation('relu'))
model.add(Dense(units=10))
model.add(Activation('softmax'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 25)        7225
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 25)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 625)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               62600
# _________________________________________________________________
# activation (Activation)      (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 71,155
# Trainable params: 71,155
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # layers.Conv2D 模型, 用作比對
#
# ![CNN_Model.png](attachment:CNN_Model.png)

# %%
#建立一個序列模型
model = Sequential()
#建立兩個卷績層, 32 個內核, 內核大小 3x3, 
#輸入影像大小 28x28x1
model.add(Dense(units=512, activation='relu', input_shape = (28, 28, 1)))
model.add(Dense(units=256, activation='relu'))
#建立一個全連接層
model.add(Dense(units=100))
model.add(Activation('relu'))

#建立一個輸出層, 並採用softmax
model.add(Dense(units=10))
model.add(Activation('softmax'))

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 28, 28, 512)       1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 28, 28, 256)       131328
# _________________________________________________________________
# dense_4 (Dense)              (None, 28, 28, 100)       25700
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 100)       0
# _________________________________________________________________
# dense_5 (Dense)              (None, 28, 28, 10)        1010
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 10)        0
# =================================================================
# Total params: 159,062
# Trainable params: 159,062
# Non-trainable params: 0
# _________________________________________________________________
# None
